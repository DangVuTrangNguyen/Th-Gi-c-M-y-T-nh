# %%
from PIL import Image
from imgtools import *

# %%
my_dir ="E:/THIGIACMAYTINH/anhBT"

# %%
# Đọc nhiều ảnh
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (736, 736)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x736>
# (720, 714)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x714>
# (736, 736)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x736>
# (600, 600)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600>
# (475, 471)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=475x471>
