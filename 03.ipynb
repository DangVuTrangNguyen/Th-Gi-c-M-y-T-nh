# %%
from PIL import Image

# %%
from imgtools import *
from IPython.display import display

# %%
my_path= "E:/THIGIACMAYTINH/anhBT/02.jpg"

# %%
# Đọc ảnh 
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x714>

# %%
print(img.size)
# Out:
# (720, 714)

# %%
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Task: lưu ảnh
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>
